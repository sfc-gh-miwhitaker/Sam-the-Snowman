-- %% [markdown]
-- # Chapter 7C - Add Python Analytics
--
-- Add a Snowpark Python procedure for anomaly detection on invoice revenue trends.
--
-- ## Learn
-- - Why this capability matters
-- - How to wire it in safely

-- %%
-- Build
-- Add or update agent tool_spec and tool_resources entries for this capability.
-- Keep naming aligned with SV_SAM_DRIFT_* and SFE_* conventions.

-- %%
-- Check
-- Run one targeted question that must route to this new capability.
-- Capture before/after behavior in notebook notes.

-- %% [markdown]
-- ## Reflect
-- Document failure modes and fallback behavior.
--
-- ## Next
-- Return to chapter 8 for final evaluation loops.
