-- %% [markdown]
-- # Chapter 2 - Break It On Purpose
--
-- Use a fixed five-question set to expose reliability issues in the thin agent.
--
-- ## Learn
-- - Why ambiguity breaks thin semantic configurations
-- - How to benchmark naive vs ontology-powered behavior

-- %% [markdown]
-- ## Hard Question Set
-- 1. Who are the top 10 customers by lifetime revenue, and what genre do they buy most of?
-- 2. For every country, compare the number of customers to the number of employees.
-- 3. Which support rep generates the most revenue, and which genre drives most of it?
-- 4. How did jazz revenue trend year over year from 2020 to 2024, compared to rock?
-- 5. Which tracks appear on the most playlists and generate the most sales?

-- %%
-- Deploy the shared hard-question dataset used across chapters 2, 6, and 8
EXECUTE IMMEDIATE FROM '@SNOWFLAKE_EXAMPLE.GIT_REPOS.SFE_SAM_THE_SNOWMAN_REPO/branches/main/evaluations/drift_evaluation_dataset.sql';

-- %%
-- Run qualitative baseline checks against naive Sam
SELECT INPUT_QUERY
FROM SNOWFLAKE_EXAMPLE.SAM_DRIFT.SAM_EVALUATION_DATA;

-- For each question, call the agent manually and capture observations in markdown notes.
-- Recommended: record whether output uses correct joins and metrics.

-- %% [markdown]
-- ## Reflect
-- This intentional failure stage creates urgency for ontology design.
--
-- ## Next
-- Open [`ch03_think_in_entities.ipynb`](ch03_think_in_entities.ipynb).
